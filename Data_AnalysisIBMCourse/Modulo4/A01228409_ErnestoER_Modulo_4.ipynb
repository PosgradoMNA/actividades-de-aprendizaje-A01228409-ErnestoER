# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01228409-ErnestoER/blob/main/Data_AnalysisIBMCourse/Modulo4/A01228409_ErnestoER_Modulo_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Instituto Tecnológico y de Estudios Superiores de Monterrey**
#
# Maestría en Inteligencia Artificial Aplicada (MNA)
#
# Ciencia y Analítica de Datos
#
# **María de la Paz Rico Fernández**
#
# # **Semana 7 - Module 4 - Model Development**
#
# **Ernesto Enriquez Rubio - A01228409**
#
# **01 de Noviembre del 2022**

# %% [markdown]
# **Linear regression**
#
# Independent variable  -> Linear regression -> Prediction
#
# **Multiple regression**
#
# Multiple independent variables -> Multiple Linear Regression -> Prediction

# %% [markdown]
# **Simple Linear Regression**
#
# y = b0 + b1x
#
# b0: the intercept
#
# b1: the slope

# %%
# X: Predictor variable
# Y: Target variable
import numpy as np

# Import linear_model from scikit-learn
from sklearn.linear_model import LinearRegression

# Create a Linear Regression Object using the constructor
lr=LinearRegression()

# %%
# Use ir.fit(X, Y) to fit the model, i.e fine the parameters b0 and b1
lr.fit(X, Y)

# Obtain a prediction
Yhat = lr.predict(X)

# Estimated Linear Model
# Intercept(b0)
lr.intercept_
# Slope (b1)
lr.coef

# %%
# Multiple Linear Regression
# Y variable: Continuous target
# X variable: Two or more predictor
# Y = b0 + b1x1 + b2x2 + b3x3 + b4x4

# b0 Intercept X=0
# B1-4: Coefficient of X1-x4

Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

lr.fit(Z, df['price'])
Yhat=lr.predict(X)
# Intercept(b0)
lr.intercept_
# Slope (b1)
lr.coef
# Multiple coeficients are expected, one per varible

# %%
# Repgression Plot
# import seaborn
import seaborn as sns
sns.regplot(x='highway-mpg', y='price', data=df)
plt.ylim(0,)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.residplot(df['highway-mpg'], df['price'])

# %% [markdown]
# **Residual Plot**
#
# ![image.png](data:image/png;base64,...)

# %%
# Distribution Plots
ax1 = sns.displot(df['price'], hist=False, color='r', label='Actual Value')
sns.distplot(Yhat, hist=False, color='b', label='Fitted Values', ax=ax1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Polynomial Regression and Pipelines
# Quadratic 2nd order
# Y = b0 + b1x1 + b2(x1)2
# Cubic 3ed order
# Y = b0 + b1x1 + b2(x1)2 + b3(x1)3
# Higher order
# Y = b0 + b1x1 + b2(x1)2 + b3(x1)3 + ...

# %%
# Calculate Polynomial of 3rd order
f=np.polyfit(X, Y, 3)
p=np.polyld(f)

# %%
from sklearn.preprocessing import PolynomialFeatures

pr=PolynomialFeatures(degree=2, include_bias=False)
x_polly=pr.fit_transform(x[['horsepower', 'curb-weight']])
pr=PolynomialFeatures(degree=2)
pr.fit_transform([1, 2], include_bias=False)

# %%
# Normalize each feature simultaneously
from sklearn.preprocessing import StandardScaler
SCALER = StandardScaler()
SCALER.fit(x[['horsepower', 'highway-mpg']])

x_scale=SCALER.transform(x[['horsepower', 'highway-mpg']])

# %%
input = [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(degree=2)), ('model', LinearRegression())]
pipe = pipeline(input)

# %% [markdown]
# **Resultado**
# ![image.png](data:image/png;base64,...)
