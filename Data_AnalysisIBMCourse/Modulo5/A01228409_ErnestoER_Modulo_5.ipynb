# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-A01228409-ErnestoER/blob/main/Data_AnalysisIBMCourse/Modulo5/A01228409_ErnestoER_Modulo_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Instituto Tecnológico y de Estudios Superiores de Monterrey**
#
# Maestría en Inteligencia Artificial Aplicada (MNA)
#
# Ciencia y Analítica de Datos
#
# **María de la Paz Rico Fernández**
#
# # **Semana 8 - Module 5 - Model Evaluation**
#
# **Ernesto Enriquez Rubio - A01228409**
#
# **08 de Noviembre del 2022**

# %% [markdown]
# # Model Evaluation
#
# Describe el desempeño del modelo entrenado.

# %%
# Separar los datos de manera aleateoria entre grupos de entrenamiento y prueba

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_data, 
                                                    y_data, 
                                                    test_size=0.3,
                                                    random_state=0)

# %% [markdown]
# # Cross Validation
#
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import cross_val_score

scores=corss_val_score(lr, x_data, y_data, cv=3)

# lr: modelo de regresión lineal
# cv: numero de particiones

 np.mean(scores)

# %%
# cross_val_predict regresa la predicción obtenida por cada elemento cuando fue parte del grupo de testeo
from sklearn.model_selection import cross_val_predict
yhat=cross_val_predit(lr2e, x_data, y_data, cv=3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Overfitting -> high complexity, considers outliers
#
#
#
# # Underfitting -> low complexity, do not follow data behavior
#
# ![image.png](data:image/png;base64,...)

# %%
# Find best degree to achieve the best model
rsqu_test = []
order = [1, 2, 3, 4]
for n in order:
  pr = PolynomialFeatures(degree=n)
  x_train_pr = pr.fit_transform(x_train[['column_name']])
  x_test_pr = pr.fit_transofrm(x_test[['column_name']])
  lr.fit(x_train_pr, y_train)
  rsqu_test.append(lr.score(x_test_pr, y_test))

# %% [markdown]
# # Regresión Ridge

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Obtain best alpha with cross validation
from sklearn.linear_model import Ridge

RigeModel = Ridge(alpha=0.1)
RigeModel.fit(X, y)

# Predict the R square 
Y_hat = RigeModel.predict(X)

# Seleccionar el alpha que maximice la R cuadrada

# %% [markdown]
# # Grid Search CV
#
# Permite probar multiples parámetros.

# %% [markdown]
# En Ridge, alpha representa un hiperparametro de la función
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSerchCV

parameters = [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 1000000],
               'normalize': [True, False]}]

RR = Ridge()

Grid1 = GridSearchCV(RR, parameters, cv=4)
Grid1.fit(x_data[['x_comlun_1', 'x_column_2']], y_data)
Grid1.best_estimator_
scores = Grid1.cv_results_
scores['mean_test_score']

# %% [markdown]
# # Calificación
#
# ![image.png](data:image/png;base64,...)
